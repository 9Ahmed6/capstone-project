# %% [markdown]
# # Experiments — Action-Based Video Understanding
#
# Scratch notebook for prototyping pipeline components week by week. Created in Week 1; populated as the project progresses.
#
# ## Week 1 sanity check
# Verify the project root is importable and configuration loads cleanly.

# %%
import json, sys
from pathlib import Path
import yaml

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

settings = yaml.safe_load((ROOT / 'configs' / 'settings.yaml').read_text())
library = json.loads((ROOT / 'schemas' / 'action_library.json').read_text())

print('Project:', settings['project']['name'], 'v' + settings['project']['version'])
print('Schema actions loaded:', len(library['actions']))

# %%
import src  # confirm package imports
print('src package version:', src.__version__)
